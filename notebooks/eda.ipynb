# %%
import pandas as pd
import numpy as  np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("../data/paysim.csv")

# %%
y = df["isFraud"]

# %%
y.value_counts(normalize=True)
# Out:
# isFraud
# 0    0.998709
# 1    0.001291
# Name: proportion, dtype: float64

# %%
plt.figure(figsize=(8,5))
sns.histplot(df[df["isFraud"]==0]["amount"], bins=50, color="blue", label="Normal", stat="density", alpha=0.6)
sns.histplot(df[df["isFraud"]==1]["amount"], bins=50, color="red", label="Fraud", stat="density", alpha=0.6)
plt.legend()
plt.title("Transaction Amount Distribution")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.countplot(data=df, x="type", hue="isFraud")
plt.title("Fraud by Transaction Type")
plt.show()
